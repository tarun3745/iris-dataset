# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
iris_data=pd.read_csv('E:\LPU\Sem 4\Summer Training\iris-flower-dataset\IRIS.csv')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris_data.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# 5           False        False         False        False    False
# 6           False        False         False        False    False
# 7           False        False         False        False    False
# 8           False        False         False        False    False
# 9           False        False         False        False    False
# 10          False        False         False        False    False
# 11          False        False         False        False    False
# 12          False        False         False        False    False
# ...

# %%
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#Mean,Min,Max of Sepal_length
g=iris_data['sepal_length'].mean()
h=iris_data['sepal_length'].min()
i=iris_data['sepal_length'].max()

# %%
print(g)
print(h)
print(i)
# Out:
# 5.843333333333335
# 4.3
# 7.9

# %%
#Mean,Min,Max of Sepal_width
a=iris_data['sepal_width'].mean()
b=iris_data['sepal_width'].min()
c=iris_data['sepal_width'].max()

# %%
print(a)
print(b)
print(c)
# Out:
# 3.0540000000000007
# 2.0
# 4.4

# %%
#Mean,Min,Max of Petal_length
d=iris_data['petal_length'].mean()
e=iris_data['petal_length'].min()
f=iris_data['petal_length'].max()

# %%
print(d)
print(e)
print(f)
# Out:
# 3.7586666666666693
# 1.0
# 6.9

# %%
#Mean,Min,Max of Petal_width
j=iris_data['petal_width'].mean()
k=iris_data['petal_width'].min()
l=iris_data['petal_width'].max()

# %%
print(j)
print(k)
print(l)
# Out:
# 1.1986666666666672
# 0.1
# 2.5

# %%
iris_data['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
iris_data.loc[iris_data['sepal_length'].idxmax()]
# Out:
# sepal_length               7.9
# sepal_width                3.8
# petal_length               6.4
# petal_width                  2
# species         Iris-virginica
# Name: 131, dtype: object

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
iris_data[iris_data['species']=='Iris-setosa']['sepal_length'].value_counts()==1
# Out:
# 5.1    False
# 5.0    False
# 5.4    False
# 4.8    False
# 4.6    False
# 4.9    False
# 4.4    False
# 5.2    False
# 5.7    False
# 4.7    False
# 5.5    False
# 5.3     True
# 5.8     True
# 4.3     True
# 4.5     True
# Name: sepal_length, dtype: bool

# %%
def find_setosa(title):
    if 'setosa' in title.lower():
        return True
    else:
        return False

# %%
sum(iris_data['species'].apply(lambda m:find_setosa(m)))
# Out:
# 50

# %%
iris_data[['species','sepal_width']].corr()
# Out:
#              sepal_width
# sepal_width          1.0

# %%
x=iris_data['sepal_length']
y=iris_data['petal_length']
plt.plot(x,'g')
plt.plot(y,'y')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('Iris length X-Y')
plt.show()

# %%
p=iris_data['sepal_width']
q=iris_data['petal_width']
plt.plot(p,'r')
plt.plot(q,'b')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.title('Iris Width P-Q')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'g--')
plt.subplot(1,2,2)
plt.plot(p,q,'r*-')

# %%
iris_data.hist(column=["sepal_length","sepal_width","petal_length","petal_width","species"],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A5B006C940>,
# ...
#       dtype=object)

# %%
fig=plt.figure()

# %%
fig=plt.figure(figsize=(15,5))
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,'g*-')
axes.set_xlabel('Sepal Length')
axes.set_ylabel('Petal Length')
axes.set_title('Iris length using Figure')
# Out:
# Text(0.5, 1.0, 'Iris length using Figure')

# %%
axes2=fig.add_axes([0.59,0.2,0.3,0.3],facecolor='c')
axes2.plot(p,q,'r--')
axes2.set_xlabel('Sepal Width')
axes2.set_ylabel('Petal Width')
axes2.set_title('Iris Width')
fig

# %%
fig.savefig("Iris length.png")

# %%
plt.hist(x) #Blue
plt.hist(y) #Orange
plt.hist(p) #Green
plt.hist(q) #Red
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <a list of 10 Patch objects>)

# %%
#seaborn
sns.distplot(x)

# %%
sns.distplot(y,hist=False,kde=True,rug=True)

# %%
sns.jointplot(x='sepal_length',y='petal_length',kind='scatter',data=iris_data,color='g')
plt.show()

# %%
sns.jointplot(x='sepal_width',y='petal_width',kind='hex',data=iris_data,color='r')
plt.show()

# %%
sns.jointplot(x='sepal_length',y='petal_width',kind='kde',data=iris_data,color='g')
plt.show()

# %%
sns.pairplot(iris_data)

# %%
sns.boxplot(data=iris_data,palette='rainbow',orient='h')

# %%
sns.boxplot(x='sepal_length',y='petal_length',data=iris_data,hue='species',palette='coolwarm')

# %%
sns.violinplot(x='sepal_width',y='petal_width',data=iris_data)

# %%
sns.catplot(x='species',y='petal_length',data=iris_data,kind='strip')

# %%
sns.factorplot(x='species',y='petal_length',data=iris_data,kind='violin')
# Out:
# C:\Users\gtaru\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.barplot(x='species',y='petal_length',data=iris_data)

# %%
sns.countplot(x='species',data=iris_data)

# %%
sns.stripplot(x='species',y='sepal_length',data=iris_data)

# %%
sns.swarmplot(x='species',y='sepal_width',data=iris_data)

# %%
sns.heatmap(iris_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.heatmap(iris_data.corr(),cmap='coolwarm')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
X=iris_data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
Y=iris_data[['species']]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# C:\Users\gtaru\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\gtaru\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\gtaru\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predictions=model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test,predictions))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      0.90      0.95        20
#  Iris-virginica       0.86      1.00      0.92        12
#
#       micro avg       0.96      0.96      0.96        45
#       macro avg       0.95      0.97      0.96        45
#    weighted avg       0.96      0.96      0.96        45

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=40)

# %%
knn.fit(X_train,Y_train)
# Out:
# C:\Users\gtaru\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=40, p=2,
#            weights='uniform')

# %%
predictions=knn.predict(X_test)

# %%
print(classification_report(Y_test,predictions))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      0.90      0.95        20
#  Iris-virginica       0.86      1.00      0.92        12
#
#       micro avg       0.96      0.96      0.96        45
#       macro avg       0.95      0.97      0.96        45
#    weighted avg       0.96      0.96      0.96        45

# %%
from sklearn import metrics
metrics.accuracy_score(predictions,Y_test)
# Out:
# 0.9555555555555556

# %%
error_rate=[]

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(Y_test,predictions))
# Out:
# [[13  0  0]
#  [ 0 18  2]
#  [ 0  0 12]]

# %%
(13+18+12)/(13+0+0+0+18+2+0+0+12)
# Out:
# 0.9555555555555556
